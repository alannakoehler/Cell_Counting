# %%
# Import necessary programs
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load base dataframe
path = "/Users/akoehler/Desktop/Cell_Counting/Cell_Counts_EC_Summary.csv"
df = pd.read_csv(path)

# %%
# Visualize 
df
# Out:
#                                                Image  Layer  Count (Red)  \
# 0  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...      1            5
# 1  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...      2            0
# 2  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...      3            6
# 3  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...      4            1
# 4  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...      5           10
# 5  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...      6           18
# 6  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...      7           18
# 7  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...      8           18
# 8  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...      9            8
# 9  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...     10            1
#
#    Count (Yellow)  Count (Green)
# 0               0             40
# 1               0            155
# 2               2             56
# ...

# %%
# Autofill BrdU injection time
df.insert(1, 'BrdU', 'e11.5')
df
# Out:
#                                                Image   BrdU  Layer  \
# 0  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5      1
# 1  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5      2
# 2  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5      3
# 3  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5      4
# 4  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5      5
# 5  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5      6
# 6  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5      7
# 7  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5      8
# 8  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5      9
# 9  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     10
#
#    Count (Red)  Count (Yellow)  Count (Green)
# 0            5               0             40
# 1            0               0            155
# 2            6               2             56
# ...

# %%
# Insert slide/section data
df.insert(2, 'Section', '55A')
df
# Out:
#                                                Image   BrdU Section  Layer  \
# 0  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A      1
# 1  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A      2
# 2  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A      3
# 3  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A      4
# 4  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A      5
# 5  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A      6
# 6  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A      7
# 7  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A      8
# 8  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A      9
# 9  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     55A     10
#
#    Count (Red)  Count (Yellow)  Count (Green)
# 0            5               0             40
# 1            0               0            155
# ...

# %%
# Insert survival to date
df.insert(2,'Survival', 'p7.5')
df
# Out:
#                                                Image   BrdU Survival Section  \
# 0  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
# 1  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
# 2  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
# 3  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
# 4  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
# 5  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
# 6  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
# 7  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
# 8  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
# 9  CD1_e10.5_p7.5_EC_RelnG10_BrdU_sl55A_20xMosaix...  e11.5     p7.5     55A
#
#    Layer  Count (Red)  Count (Yellow)  Count (Green)
# 0      1            5               0             40
# ...

# %%
# Delete image name column
del df['Image']
df
# Out:
#     BrdU Survival Section  Layer  Count (Red)  Count (Yellow)  Count (Green)
# 0  e11.5     p7.5     55A      1            5               0             40
# 1  e11.5     p7.5     55A      2            0               0            155
# 2  e11.5     p7.5     55A      3            6               2             56
# 3  e11.5     p7.5     55A      4            1               0             22
# 4  e11.5     p7.5     55A      5           10               3             29
# 5  e11.5     p7.5     55A      6           18               0             22
# 6  e11.5     p7.5     55A      7           18               0             14
# 7  e11.5     p7.5     55A      8           18               0              4
# 8  e11.5     p7.5     55A      9            8               0              3
# 9  e11.5     p7.5     55A     10            1               0              1

# %%
# Generate a bar plot
ax = plt.gca()
df.plot(kind = 'bar', x = 'Layer', y = "Count (Green)", color = 'green', ax = ax)
df.plot(kind = 'bar', x = 'Layer', y = "Count (Red)", color = 'red', ax = ax)
df.plot(kind = 'bar', x = 'Layer', y = 'Count (Yellow)', color = 'yellow', ax = ax)
plt.show()
